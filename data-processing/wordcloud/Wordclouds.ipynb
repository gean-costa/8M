# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %% [markdown]
# ## Português

# %%
with open('../../data-pre-processing/2csv/cenario1_8M2021_tweets_pt.txt', 'r') as file:
    tweets_pt = file.readlines()
    
palavras = ','.join(list(tweets_pt))

# Generate a word cloud image
nuvem_palavras = WordCloud(background_color='white', width=1280, height=720).generate(palavras)

# Display the generated image:
# the matplotlib way:
plt.figure(figsize = (15,15))
plt.axis("off")
plt.imshow(nuvem_palavras, interpolation = 'bilinear')
plt.show()

nuvem_palavras.to_file('21wordcloud-pt-1.png')

# %%
with open('../../data-pre-processing/2csv/cenario2_8M2021_tweets_pt.txt', 'r') as file:
    tweets_pt = file.readlines()
    
palavras = ','.join(list(tweets_pt))

# Generate a word cloud image
nuvem_palavras = WordCloud(background_color='white', width=1280, height=720).generate(palavras)

# Display the generated image:
# the matplotlib way:
plt.figure(figsize = (15,15))
plt.axis("off")
plt.imshow(nuvem_palavras, interpolation = 'bilinear')
plt.show()

nuvem_palavras.to_file('21wordcloud-pt-2.png')

# %% [markdown]
# ## Espanhol

# %%
with open('../../data-pre-processing/2csv/cenario1_8M2021_tweets_es.txt', 'r') as file:
    tweets_es = file.readlines()
    
palabras = ','.join(list(tweets_es))

# Generate a word cloud image
nube_palabras = WordCloud(background_color='white', width=1280, height=720).generate(palabras)

# Display the generated image:
# the matplotlib way:
plt.figure(figsize = (15,15))
plt.axis("off")
plt.imshow(nube_palabras, interpolation = 'bilinear')
plt.show()

nube_palabras.to_file('21wordcloud-es-1.png')

# %%
with open('../../data-pre-processing/2csv/cenario2_8M2021_tweets_es.txt', 'r') as file:
    tweets_es = file.readlines()
    
palabras = ','.join(list(tweets_es))

# Generate a word cloud image
nube_palabras = WordCloud(background_color='white', 
                          width=1280, 
                          height=720).generate(palabras)

# Display the generated image:
# the matplotlib way:
plt.figure(figsize = (15,15))
plt.axis("off")
plt.imshow(nube_palabras, interpolation = 'bilinear')
plt.show()

nube_palabras.to_file('21wordcloud-es-2.png')

# %% [markdown]
# ## Inglês

# %%
with open('../../data-pre-processing/2csv/cenario1_8M2021_tweets_en.txt', 'r') as file:
    tweets_en = file.readlines()
    
words = ','.join(list(tweets_en))

# Generate a word cloud image
wordcloud = WordCloud(background_color='white', width=1280, height=720).generate(words)

# Display the generated image:
# the matplotlib way:
plt.figure(figsize = (15,15))
plt.axis("off")
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.show()

wordcloud.to_file('21wordcloud-en-1.png')

# %%
with open('../../data-pre-processing/2csv/cenario2_8M2021_tweets_en.txt', 'r') as file:
    tweets_en = file.readlines()
    
words = ','.join(list(tweets_en))

# Generate a word cloud image
wordcloud = WordCloud(background_color='white', width=1280, height=720).generate(words)

# Display the generated image:
# the matplotlib way:
plt.figure(figsize = (15,15))
plt.axis("off")
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.show()

wordcloud.to_file('21wordcloud-en-2.png')
